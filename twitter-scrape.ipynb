# %%
import nest_asyncio
import twint
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import re
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords

from textblob import TextBlob

from wordcloud import WordCloud

# %%
nest_asyncio.apply()

keywords = {"astrotraffic":"kltrafficupdate"}
#"Malaysia":"Motor insurance OR \"vehicle insurance\" OR \"car insurance\"",
#"Malaysia":"flood insurance",
#"Malaysia flood": "#malaysiaflood"}

def twintConfig(date_from,date_to,search_string):
    c = twint.Config()
    c.Search = search_string[1]
    c.Since = date_from
    c.Until = date_to
    c.Pandas = True
    twint.run.Search(c)

since = "2021-09-08"#input ("Start date: ")
until = "2022-09-09"#input ("End date: ")
    
    
def Run_Twint(search_values):
    df = pd.DataFrame()
    
    for keyword in search_values.items():
        twintConfig(since,until,keyword)
        tweets_df = twint.storage.panda.Tweets_df
        tweets_df["Keyword"] = keyword[0]
        df = pd.concat([df,tweets_df])
    
    return df

# %%
tweets_df = Run_Twint(keywords)
# Out:
# 1567678463380946945 2022-09-08 08:57:26 +0800 <mohdadrian> @astrotraffic @kltrafficupdate Why are lorries on the road during peak hours?
# 1566740609951748096 2022-09-05 18:50:44 +0800 <AdamELMuqri> @astrotraffic @kltrafficupdate How come our highways are jammed almost everyday now?
# 1566675701482520576 2022-09-05 14:32:49 +0800 <YussyafiqahY> Masalahnya saya dapat cara tanpa perlu ada #PRU15  @kltrafficupdate @usembassykl @ManUtd @unimalaya @uputramalaysia
# 1566446572678029313 2022-09-04 23:22:20 +0800 <akram2k> @mySUKEofficial @LLMinfotrafik @JKRMalaysia @MOWorks @JKR_Hulu_Langat @KLCCC_DBKL @astrotraffic @RakitaTraffic @cheras_info @PDRMsia_Trafik @kltrafficupdate Uturn di shell BTS, hadapan maju linq dari arah kesas menuju ulu klang sudah dibuka semula?
# 1566436834749579268 2022-09-04 22:43:39 +0800 <anyimadu211> @ReadFiGlobal @kltrafficupdate @XRebellionUK @OR13b Bitmart
# ...

# %%
tweets_df.head(10)
# Out:
#                     id      conversation_id    created_at  \
# 0  1567678463380946945  1567665824667955200  1.662599e+12
# 1  1566740609951748096  1566737731040210944  1.662375e+12
# 2  1566675701482520576  1566675701482520576  1.662360e+12
# 3  1566446572678029313  1566416367263240192  1.662305e+12
# 4  1566436834749579268  1565644070340403200  1.662303e+12
# 5  1564414155301748736  1564414155301748736  1.661820e+12
# 6  1564407528636948480  1564407528636948480  1.661819e+12
# 7  1564192241354436608  1564192241354436608  1.661767e+12
# 8  1562998002200895489  1562990653961011201  1.661483e+12
# 9  1562967755740958722  1562952113868910595  1.661476e+12
#
#                   date timezone place  \
# 0  2022-09-08 08:57:26    +0800
# 1  2022-09-05 18:50:44    +0800
# 2  2022-09-05 14:32:49    +0800
# 3  2022-09-04 23:22:20    +0800
# 4  2022-09-04 22:43:39    +0800
# 5  2022-08-30 08:46:14    +0800
# 6  2022-08-30 08:19:54    +0800
# 7  2022-08-29 18:04:26    +0800
# ...
